# %% [markdown]
# # TinyGD - A Friendly Implementation of Gradient Descent

# %% [markdown]
# ### This is a simplified introduction to implementing and visualizing the Gradient Descent algorithm and fine-tuning our intuition about it.
#
# ### Let's begin.

# %% [markdown]
# **Say we have a function, let's make it something simple: **
# ### y = (x+5)<sup>2</sup>
#
# * This function is nothing but a mapping of the relationship between x's and y's.
#
# **We can take several x's and get corresponding y's that obey this function. Let us try to do that!**

# %%
# Importing the required Python libraries

import matplotlib.pyplot as plt
import numpy as np

# %%
# Getting 100 random points for x
# np.linspace(-10,10,100) returns 100 evenly spaced numbers in the range of -10 to 10

x = np.linspace(10,-10,100)

# Defining our function

y = (x+5)**2

# %%
# Plotting the function as a graph

fig, ax = plt.subplots()

# Setting x and y axes' scale

plt.xlim([-10,5])
plt.ylim([0,50])

ax.plot(x,y)

plt.show()

# %% [markdown]
# **Suppose we want to find the _Local Minima_, what do we do?**
#
# **By looking at the above graph we can intuitively say that the Local Minima occurs at the following points :
#             y = 0 and x = -5.** (When we plug y = 0 into our function, we get x = -5)
#
# **Let us write a few lines of code in order to obtain this result using Gradient Descent.**

# %% [markdown]
# ### Suppose we are standing on the slope of the above graph at point x = 2 and we attempt to slowly walk our way down to the Local Minima. We take _n_ tiny steps on our way, let us call this step alpha(also called the learning rate).
#
# ### If the process of taking each optimally selected step downhill is called one iteration, how many iterations will it take for us to reach local minima? Here's the algorithm to compute that!

# %%
# Initializing the algorithm at 2

current_position = 2

# Setting the learning rate to be 0.01

alpha = 0.01

# Precision is used to stop our algorithm.
# If we have a result that is precise to our level of satisfaction, we stop running the algo!

"""If the difference between our current position and our updated position after taking 
a step down becomes < precision, our algorithm will stop iterating because we are where we want to be!

I want my algorithm to be precise to the order of magnitude of 10^-6, so I am setting precision as follows:"""

precision = 0.000001 

# Initializing the step_size variable = 1 in order to compare and compute precision.

step_size = 1 

# We don't want to take more than 10,000 steps!(Obviously)
# In fact, we want to reach Local Minima in the least number of steps possible.
# If the number of our iterations becomes more than 10000, our algorithm will stop.

max_iters = 10000 

# We will store the number of iterations in the iters variable which will keep getting updated after each iteration.
# Let us initialize it to 0 at our starting point.

iters = 0 

# Defining our Gradient Descent function.
# 2*(x+5) because f(x) = (x+5)**2 and df/dx = 2*(x+5)

df = lambda x: 2*(x+5)

# %% [markdown]
# ## Just a little calculus to help us along :
#
# ## dy/dx is also known as the Gradient of our function. Hence _Gradient_ Descent!
#
# ### Since f(x) = y = (x+5)<sup>2</sup>, dy/dx or rate of change of y with respect to x will be  = 2*(x+5)

# %% [markdown]
# ### Not sure how that works? Let's look at the math :

# %%
from IPython.display import Image
PATH = "/home/allomorph/Downloads/"
Image(filename = PATH + "gradientderivative.jpg")

# %% [markdown]
# ## Back to our algorithm :
#
# ### At any given point x, dy/dx will be the gradient of that point. When we take a step down, our new position is computed by multiplying our gradient derivative df of our previous postion with learning rate alpha and subtracting the result from our position.

# %%
while step_size > precision and iters < max_iters:
    
    # After taking each step we store the position of our previous step in prev_position
    prev_position = current_position 
    
    # Updating our new position calculated using a simple formula
    current_position = current_position - alpha*df(prev_position)
    
    # Updating the change in our position
    step_size = abs(current_position - prev_position)
    
    # Counting number of iterations
    iters += 1
    
    # Printing the progress of our journey down the slope! ^.^
    print("On Iteration {}, step size is {} and our updated position is {}\n\n----\n\n".format(iters,float(step_size),current_position))
# Out:
# On Iteration 1, step size is 0.14000000000000012 and our updated position is 1.8599999999999999
#
# ----
#
#
# On Iteration 2, step size is 0.1372 and our updated position is 1.7227999999999999
#
# ----
#
#
# On Iteration 3, step size is 0.1344559999999999 and our updated position is 1.588344
#
# ----
#
#
# On Iteration 4, step size is 0.13176688000000003 and our updated position is 1.45657712
#
# ----
#
#
# On Iteration 5, step size is 0.12913154240000013 and our updated position is 1.3274455775999998
#
# ----
#
#
# On Iteration 6, step size is 0.126548911552 and our updated position is 1.2008966660479998
#
# ----
#
#
# On Iteration 7, step size is 0.12401793332096012 and our updated position is 1.0768787327270397
#
# ----
#
#
# On Iteration 8, step size is 0.12153757465454085 and our updated position is 0.9553411580724989
#
# ----
#
#
# On Iteration 9, step size is 0.11910682316144994 and our updated position is 0.8362343349110489
#
# ----
#
#
# On Iteration 10, step size is 0.116724686698221 and our updated position is 0.7195096482128279
#
# ----
#
#
# On Iteration 11, step size is 0.11439019296425657 and our updated position is 0.6051194552485714
#
# ----
#
#
# On Iteration 12, step size is 0.11210238910497144 and our updated position is 0.4930170661435999
#
# ----
#
#
# On Iteration 13, step size is 0.10986034132287198 and our updated position is 0.38315672482072793
#
# ----
#
#
# On Iteration 14, step size is 0.10766313449641457 and our updated position is 0.27549359032431336
#
# ----
#
#
# On Iteration 15, step size is 0.10550987180648624 and our updated position is 0.16998371851782712
#
# ----
#
#
# On Iteration 16, step size is 0.10339967437035653 and our updated position is 0.06658404414747059
#
# ----
#
#
# On Iteration 17, step size is 0.10133168088294942 and our updated position is -0.03474763673547883
#
# ----
#
#
# On Iteration 18, step size is 0.09930504726529042 and our updated position is -0.13405268400076925
#
# ----
#
#
# On Iteration 19, step size is 0.09731894631998461 and our updated position is -0.23137163032075386
#
# ----
#
#
# On Iteration 20, step size is 0.0953725673935849 and our updated position is -0.32674419771433877
#
# ----
#
#
# On Iteration 21, step size is 0.09346511604571323 and our updated position is -0.420209313760052
#
# ----
#
#
# On Iteration 22, step size is 0.09159581372479897 and our updated position is -0.511805127484851
#
# ----
#
#
# On Iteration 23, step size is 0.089763897450303 and our updated position is -0.601569024935154
#
# ----
#
#
# On Iteration 24, step size is 0.08796861950129697 and our updated position is -0.6895376444364509
#
# ----
#
#
# On Iteration 25, step size is 0.08620924711127098 and our updated position is -0.7757468915477219
#
# ----
#
#
# On Iteration 26, step size is 0.08448506216904561 and our updated position is -0.8602319537167675
#
# ----
#
#
# On Iteration 27, step size is 0.08279536092566464 and our updated position is -0.9430273146424322
#
# ----
#
#
# On Iteration 28, step size is 0.08113945370715148 and our updated position is -1.0241667683495836
#
# ----
#
#
# On Iteration 29, step size is 0.07951666463300833 and our updated position is -1.103683432982592
#
# ----
#
#
# On Iteration 30, step size is 0.07792633134034821 and our updated position is -1.1816097643229402
#
# ----
#
#
# On Iteration 31, step size is 0.07636780471354121 and our updated position is -1.2579775690364814
#
# ----
#
#
# On Iteration 32, step size is 0.07484044861927042 and our updated position is -1.3328180176557518
#
# ----
#
#
# On Iteration 33, step size is 0.07334363964688495 and our updated position is -1.4061616573026368
#
# ----
#
#
# On Iteration 34, step size is 0.07187676685394728 and our updated position is -1.478038424156584
#
# ----
#
#
# On Iteration 35, step size is 0.07043923151686826 and our updated position is -1.5484776556734523
#
# ----
#
#
# On Iteration 36, step size is 0.06903044688653104 and our updated position is -1.6175081025599833
#
# ----
#
#
# On Iteration 37, step size is 0.06764983794880042 and our updated position is -1.6851579405087838
#
# ----
#
#
# On Iteration 38, step size is 0.06629684118982437 and our updated position is -1.7514547816986081
#
# ----
#
#
# On Iteration 39, step size is 0.06497090436602782 and our updated position is -1.816425686064636
#
# ----
#
#
# On Iteration 40, step size is 0.06367148627870733 and our updated position is -1.8800971723433433
#
# ----
#
#
# On Iteration 41, step size is 0.06239805655313324 and our updated position is -1.9424952288964765
#
# ----
#
#
# On Iteration 42, step size is 0.06115009542207028 and our updated position is -2.003645324318547
#
# ----
#
#
# On Iteration 43, step size is 0.059927093513628904 and our updated position is -2.0635724178321757
#
# ----
#
#
# On Iteration 44, step size is 0.05872855164335666 and our updated position is -2.1223009694755324
#
# ----
#
#
# On Iteration 45, step size is 0.05755398061048922 and our updated position is -2.1798549500860216
#
# ----
#
#
# On Iteration 46, step size is 0.05640290099827938 and our updated position is -2.236257851084301
#
# ----
#
#
# On Iteration 47, step size is 0.05527484297831409 and our updated position is -2.291532694062615
#
# ----
#
#
# On Iteration 48, step size is 0.054169346118747796 and our updated position is -2.345702040181363
#
# ----
#
#
# On Iteration 49, step size is 0.05308595919637282 and our updated position is -2.3987879993777357
#
# ----
#
#
# On Iteration 50, step size is 0.05202424001244532 and our updated position is -2.450812239390181
#
# ----
#
#
# On Iteration 51, step size is 0.050983755212196336 and our updated position is -2.5017959946023773
#
# ----
#
#
# On Iteration 52, step size is 0.04996408010795239 and our updated position is -2.5517600747103297
#
# ----
#
#
# On Iteration 53, step size is 0.04896479850579327 and our updated position is -2.600724873216123
#
# ----
#
#
# On Iteration 54, step size is 0.04798550253567768 and our updated position is -2.6487103757518007
#
# ----
#
#
# On Iteration 55, step size is 0.04702579248496397 and our updated position is -2.6957361682367647
#
# ----
#
#
# On Iteration 56, step size is 0.04608527663526463 and our updated position is -2.7418214448720293
#
# ----
#
#
# On Iteration 57, step size is 0.04516357110255953 and our updated position is -2.786985015974589
#
# ----
#
#
# On Iteration 58, step size is 0.044260299680508375 and our updated position is -2.831245315655097
#
# ----
#
#
# On Iteration 59, step size is 0.04337509368689796 and our updated position is -2.874620409341995
#
# ----
#
#
# On Iteration 60, step size is 0.042507591813159884 and our updated position is -2.917128001155155
#
# ----
#
#
# On Iteration 61, step size is 0.04165743997689697 and our updated position is -2.958785441132052
#
# ----
#
#
# On Iteration 62, step size is 0.04082429117735886 and our updated position is -2.999609732309411
#
# ----
#
#
# On Iteration 63, step size is 0.040007805353811765 and our updated position is -3.0396175376632226
#
# ----
#
#
# On Iteration 64, step size is 0.0392076492467357 and our updated position is -3.0788251869099583
#
# ----
#
#
# On Iteration 65, step size is 0.03842349626180086 and our updated position is -3.117248683171759
#
# ----
#
#
# On Iteration 66, step size is 0.03765502633656492 and our updated position is -3.154903709508324
#
# ----
#
#
# On Iteration 67, step size is 0.036901925809833536 and our updated position is -3.1918056353181576
#
# ----
#
#
# On Iteration 68, step size is 0.036163887293636954 and our updated position is -3.2279695226117946
#
# ----
#
#
# On Iteration 69, step size is 0.03544060954776418 and our updated position is -3.2634101321595588
#
# ----
#
#
# On Iteration 70, step size is 0.03473179735680887 and our updated position is -3.2981419295163676
#
# ----
#
#
# On Iteration 71, step size is 0.034037161409672834 and our updated position is -3.3321790909260405
#
# ----
#
#
# On Iteration 72, step size is 0.033356418181479164 and our updated position is -3.3655355091075196
#
# ----
#
#
# On Iteration 73, step size is 0.03268928981784969 and our updated position is -3.3982247989253693
#
# ----
#
#
# On Iteration 74, step size is 0.03203550402149258 and our updated position is -3.430260302946862
#
# ----
#
#
# On Iteration 75, step size is 0.031394793941062815 and our updated position is -3.4616550968879247
#
# ----
#
#
# On Iteration 76, step size is 0.03076689806224131 and our updated position is -3.492421994950166
#
# ----
#
#
# On Iteration 77, step size is 0.030151560100996733 and our updated position is -3.5225735550511628
#
# ----
#
#
# On Iteration 78, step size is 0.029548528898976745 and our updated position is -3.5521220839501395
#
# ----
#
#
# On Iteration 79, step size is 0.028957558320997112 and our updated position is -3.5810796422711366
#
# ----
#
#
# On Iteration 80, step size is 0.02837840715457718 and our updated position is -3.609458049425714
#
# ----
#
#
# On Iteration 81, step size is 0.027810839011485733 and our updated position is -3.6372688884371995
#
# ----
#
#
# On Iteration 82, step size is 0.027254622231255965 and our updated position is -3.6645235106684555
#
# ----
#
#
# On Iteration 83, step size is 0.02670952978663088 and our updated position is -3.6912330404550864
#
# ----
#
#
# On Iteration 84, step size is 0.026175339190898317 and our updated position is -3.7174083796459847
#
# ----
#
#
# On Iteration 85, step size is 0.025651832407080466 and our updated position is -3.743060212053065
#
# ----
#
#
# On Iteration 86, step size is 0.025138795758938848 and our updated position is -3.768199007812004
#
# ----
#
#
# On Iteration 87, step size is 0.02463601984376007 and our updated position is -3.792835027655764
#
# ----
#
#
# On Iteration 88, step size is 0.024143299446884647 and our updated position is -3.8169783271026487
#
# ----
#
#
# On Iteration 89, step size is 0.023660433457946883 and our updated position is -3.8406387605605956
#
# ----
#
#
# On Iteration 90, step size is 0.023187224788788097 and our updated position is -3.8638259853493837
#
# ----
#
#
# On Iteration 91, step size is 0.02272348029301252 and our updated position is -3.8865494656423962
#
# ----
#
#
# On Iteration 92, step size is 0.022269010687152146 and our updated position is -3.9088184763295484
#
# ----
#
#
# On Iteration 93, step size is 0.02182363047340896 and our updated position is -3.9306421068029573
#
# ----
#
#
# On Iteration 94, step size is 0.021387157863940853 and our updated position is -3.952029264666898
#
# ----
#
#
# On Iteration 95, step size is 0.02095941470666185 and our updated position is -3.97298867937356
#
# ----
#
#
# On Iteration 96, step size is 0.020540226412528728 and our updated position is -3.9935289057860888
#
# ----
#
#
# On Iteration 97, step size is 0.02012942188427802 and our updated position is -4.013658327670367
#
# ----
#
#
# On Iteration 98, step size is 0.019726833446592984 and our updated position is -4.03338516111696
#
# ----
#
#
# On Iteration 99, step size is 0.019332296777660574 and our updated position is -4.05271745789462
#
# ----
#
#
# On Iteration 100, step size is 0.018945650842107753 and our updated position is -4.071663108736728
#
# ----
#
#
# On Iteration 101, step size is 0.018566737825265633 and our updated position is -4.090229846561994
#
# ----
#
#
# On Iteration 102, step size is 0.018195403068760108 and our updated position is -4.108425249630754
#
# ----
#
#
# On Iteration 103, step size is 0.017831495007384568 and our updated position is -4.126256744638138
#
# ----
#
#
# On Iteration 104, step size is 0.01747486510723739 and our updated position is -4.143731609745376
#
# ----
#
#
# On Iteration 105, step size is 0.017125367805092218 and our updated position is -4.160856977550468
#
# ----
#
#
# On Iteration 106, step size is 0.016782860448990355 and our updated position is -4.177639837999458
#
# ----
#
#
# On Iteration 107, step size is 0.01644720324001092 and our updated position is -4.194087041239469
#
# ----
#
#
# On Iteration 108, step size is 0.016118259175210703 and our updated position is -4.21020530041468
#
# ----
#
#
# On Iteration 109, step size is 0.015795893991706222 and our updated position is -4.226001194406386
#
# ----
#
#
# On Iteration 110, step size is 0.01547997611187224 and our updated position is -4.2414811705182585
#
# ----
#
#
# On Iteration 111, step size is 0.015170376589634493 and our updated position is -4.256651547107893
#
# ----
#
#
# On Iteration 112, step size is 0.01486696905784246 and our updated position is -4.271518516165735
#
# ----
#
#
# On Iteration 113, step size is 0.014569629676684848 and our updated position is -4.28608814584242
#
# ----
#
#
# On Iteration 114, step size is 0.014278237083151346 and our updated position is -4.300366382925572
#
# ----
#
#
# On Iteration 115, step size is 0.013992672341488266 and our updated position is -4.31435905526706
#
# ----
#
#
# On Iteration 116, step size is 0.013712818894658696 and our updated position is -4.328071874161719
#
# ----
#
#
# On Iteration 117, step size is 0.013438562516765451 and our updated position is -4.341510436678484
#
# ----
#
#
# On Iteration 118, step size is 0.013169791266430586 and our updated position is -4.354680227944915
#
# ----
#
#
# On Iteration 119, step size is 0.012906395441101282 and our updated position is -4.367586623386016
#
# ----
#
#
# On Iteration 120, step size is 0.012648267532279434 and our updated position is -4.380234890918295
#
# ----
#
#
# On Iteration 121, step size is 0.012395302181634094 and our updated position is -4.392630193099929
#
# ----
#
#
# On Iteration 122, step size is 0.012147396138001199 and our updated position is -4.404777589237931
#
# ----
#
#
# On Iteration 123, step size is 0.011904448215241281 and our updated position is -4.416682037453172
#
# ----
#
#
# On Iteration 124, step size is 0.011666359250936509 and our updated position is -4.428348396704108
#
# ----
#
#
# On Iteration 125, step size is 0.01143303206591817 and our updated position is -4.439781428770027
#
# ----
#
#
# On Iteration 126, step size is 0.011204371424599735 and our updated position is -4.450985800194626
#
# ----
#
#
# On Iteration 127, step size is 0.01098028399610751 and our updated position is -4.461966084190734
#
# ----
#
#
# On Iteration 128, step size is 0.010760678316185768 and our updated position is -4.47272676250692
#
# ----
#
#
# On Iteration 129, step size is 0.010545464749861289 and our updated position is -4.483272227256781
#
# ----
#
#
# On Iteration 130, step size is 0.010334555454864613 and our updated position is -4.4936067827116455
#
# ----
#
#
# On Iteration 131, step size is 0.010127864345767179 and our updated position is -4.503734647057413
#
# ----
#
#
# On Iteration 132, step size is 0.009925307058852084 and our updated position is -4.513659954116265
#
# ----
#
#
# On Iteration 133, step size is 0.009726800917674971 and our updated position is -4.52338675503394
#
# ----
#
#
# On Iteration 134, step size is 0.009532264899321241 and our updated position is -4.532919019933261
#
# ----
#
#
# On Iteration 135, step size is 0.009341619601334727 and our updated position is -4.542260639534596
#
# ----
#
#
# On Iteration 136, step size is 0.009154787209308068 and our updated position is -4.551415426743904
#
# ----
#
#
# On Iteration 137, step size is 0.008971691465122333 and our updated position is -4.560387118209026
#
# ----
#
#
# On Iteration 138, step size is 0.008792257635819034 and our updated position is -4.569179375844845
#
# ----
#
#
# On Iteration 139, step size is 0.008616412483102742 and our updated position is -4.577795788327948
#
# ----
#
#
# On Iteration 140, step size is 0.008444084233441451 and our updated position is -4.586239872561389
#
# ----
#
#
# On Iteration 141, step size is 0.008275202548771787 and our updated position is -4.594515075110161
#
# ----
#
#
# On Iteration 142, step size is 0.008109698497796636 and our updated position is -4.602624773607958
#
# ----
#
#
# On Iteration 143, step size is 0.007947504527840543 and our updated position is -4.610572278135798
#
# ----
#
#
# On Iteration 144, step size is 0.007788554437284212 and our updated position is -4.6183608325730825
#
# ----
#
#
# On Iteration 145, step size is 0.007632783348538119 and our updated position is -4.625993615921621
#
# ----
#
#
# On Iteration 146, step size is 0.007480127681567694 and our updated position is -4.633473743603188
#
# ----
#
#
# On Iteration 147, step size is 0.007330525127936305 and our updated position is -4.640804268731125
#
# ----
#
#
# On Iteration 148, step size is 0.0071839146253775965 and our updated position is -4.647988183356502
#
# ----
#
#
# On Iteration 149, step size is 0.007040236332869654 and our updated position is -4.655028419689372
#
# ----
#
#
# On Iteration 150, step size is 0.006899431606212758 and our updated position is -4.661927851295585
#
# ----
#
#
# On Iteration 151, step size is 0.0067614429740885384 and our updated position is -4.668689294269673
#
# ----
#
#
# On Iteration 152, step size is 0.006626214114606732 and our updated position is -4.67531550838428
#
# ----
#
#
# On Iteration 153, step size is 0.006493689832314686 and our updated position is -4.681809198216595
#
# ----
#
#
# On Iteration 154, step size is 0.006363816035667824 and our updated position is -4.688173014252262
#
# ----
#
#
# On Iteration 155, step size is 0.0062365397149548585 and our updated position is -4.694409553967217
#
# ----
#
#
# On Iteration 156, step size is 0.006111808920655548 and our updated position is -4.700521362887873
#
# ----
#
#
# On Iteration 157, step size is 0.005989572742242544 and our updated position is -4.706510935630115
#
# ----
#
#
# On Iteration 158, step size is 0.005869781287398013 and our updated position is -4.712380716917513
#
# ----
#
#
# On Iteration 159, step size is 0.005752385661649484 and our updated position is -4.718133102579163
#
# ----
#
#
# On Iteration 160, step size is 0.005637337948416921 and our updated position is -4.72377044052758
#
# ----
#
#
# On Iteration 161, step size is 0.005524591189448813 and our updated position is -4.729295031717029
#
# ----
#
#
# On Iteration 162, step size is 0.00541409936565973 and our updated position is -4.734709131082688
#
# ----
#
#
# On Iteration 163, step size is 0.005305817378346234 and our updated position is -4.7400149484610345
#
# ----
#
#
# On Iteration 164, step size is 0.00519970103077938 and our updated position is -4.745214649491814
#
# ----
#
#
# On Iteration 165, step size is 0.005095707010164041 and our updated position is -4.750310356501978
#
# ----
#
#
# On Iteration 166, step size is 0.0049937928699606005 and our updated position is -4.755304149371939
#
# ----
#
#
# On Iteration 167, step size is 0.004893917012561033 and our updated position is -4.7601980663845
#
# ----
#
#
# On Iteration 168, step size is 0.004796038672309599 and our updated position is -4.764994105056809
#
# ----
#
#
# On Iteration 169, step size is 0.004700117898863709 and our updated position is -4.769694222955673
#
# ----
#
#
# On Iteration 170, step size is 0.004606115540886968 and our updated position is -4.77430033849656
#
# ----
#
#
# On Iteration 171, step size is 0.004513993230069069 and our updated position is -4.778814331726629
#
# ----
#
#
# On Iteration 172, step size is 0.004423713365467208 and our updated position is -4.783238045092096
#
# ----
#
#
# On Iteration 173, step size is 0.004335239098158361 and our updated position is -4.7875732841902545
#
# ----
#
#
# On Iteration 174, step size is 0.004248534316195318 and our updated position is -4.79182181850645
#
# ----
#
#
# On Iteration 175, step size is 0.0041635636298709144 and our updated position is -4.795985382136321
#
# ----
#
#
# On Iteration 176, step size is 0.004080292357273585 and our updated position is -4.800065674493594
#
# ----
#
#
# On Iteration 177, step size is 0.0039986865101280245 and our updated position is -4.804064361003722
#
# ----
#
#
# On Iteration 178, step size is 0.003918712779925393 and our updated position is -4.807983073783648
#
# ----
#
#
# On Iteration 179, step size is 0.0038403385243270804 and our updated position is -4.811823412307975
#
# ----
#
#
# On Iteration 180, step size is 0.0037635317538402546 and our updated position is -4.815586944061815
#
# ----
#
#
# On Iteration 181, step size is 0.003688261118763414 and our updated position is -4.8192752051805785
#
# ----
#
#
# On Iteration 182, step size is 0.0036144958963886253 and our updated position is -4.822889701076967
#
# ----
#
#
# On Iteration 183, step size is 0.0035422059784604443 and our updated position is -4.826431907055428
#
# ----
#
#
# On Iteration 184, step size is 0.0034713618588915196 and our updated position is -4.829903268914319
#
# ----
#
#
# On Iteration 185, step size is 0.003401934621713565 and our updated position is -4.833305203536033
#
# ----
#
#
# On Iteration 186, step size is 0.0033338959292796844 and our updated position is -4.836639099465312
#
# ----
#
#
# On Iteration 187, step size is 0.003267218010694073 and our updated position is -4.839906317476006
#
# ----
#
#
# On Iteration 188, step size is 0.0032018736504797474 and our updated position is -4.843108191126486
#
# ----
#
#
# On Iteration 189, step size is 0.003137836177470099 and our updated position is -4.846246027303956
#
# ----
#
#
# On Iteration 190, step size is 0.003075079453920715 and our updated position is -4.849321106757877
#
# ----
#
#
# On Iteration 191, step size is 0.003013577864842354 and our updated position is -4.852334684622719
#
# ----
#
#
# On Iteration 192, step size is 0.0029533063075453114 and our updated position is -4.855287990930265
#
# ----
#
#
# On Iteration 193, step size is 0.002894240181394281 and our updated position is -4.858182231111659
#
# ----
#
#
# On Iteration 194, step size is 0.0028363553777666084 and our updated position is -4.8610185864894255
#
# ----
#
#
# On Iteration 195, step size is 0.0027796282702112762 and our updated position is -4.863798214759637
#
# ----
#
#
# On Iteration 196, step size is 0.0027240357048068375 and our updated position is -4.866522250464444
#
# ----
#
#
# On Iteration 197, step size is 0.002669554990711198 and our updated position is -4.869191805455155
#
# ----
#
#
# On Iteration 198, step size is 0.0026161638908970275 and our updated position is -4.871807969346052
#
# ----
#
#
# On Iteration 199, step size is 0.002563840613079016 and our updated position is -4.874371809959131
#
# ----
#
#
# On Iteration 200, step size is 0.0025125638008169915 and our updated position is -4.876884373759948
#
# ----
#
#
# On Iteration 201, step size is 0.0024623125248011135 and our updated position is -4.879346686284749
#
# ----
#
#
# On Iteration 202, step size is 0.0024130662743049314 and our updated position is -4.881759752559054
#
# ----
#
#
# On Iteration 203, step size is 0.002364804948818744 and our updated position is -4.884124557507873
#
# ----
#
#
# On Iteration 204, step size is 0.002317508849842831 and our updated position is -4.8864420663577155
#
# ----
#
#
# On Iteration 205, step size is 0.0022711586728458855 and our updated position is -4.888713225030561
#
# ----
#
#
# On Iteration 206, step size is 0.002225735499388648 and our updated position is -4.89093896052995
#
# ----
#
#
# On Iteration 207, step size is 0.002181220789401195 and our updated position is -4.893120181319351
#
# ----
#
#
# On Iteration 208, step size is 0.0021375963736129933 and our updated position is -4.895257777692964
#
# ----
#
#
# On Iteration 209, step size is 0.002094844446141053 and our updated position is -4.897352622139105
#
# ----
#
#
# On Iteration 210, step size is 0.0020529475572175215 and our updated position is -4.899405569696323
#
# ----
#
#
# On Iteration 211, step size is 0.0020118886060735974 and our updated position is -4.901417458302396
#
# ----
#
#
# On Iteration 212, step size is 0.001971650833952232 and our updated position is -4.903389109136349
#
# ----
#
#
# On Iteration 213, step size is 0.0019322178172727078 and our updated position is -4.905321326953621
#
# ----
#
#
# On Iteration 214, step size is 0.0018935734609275556 and our updated position is -4.907214900414549
#
# ----
#
#
# On Iteration 215, step size is 0.0018557019917091466 and our updated position is -4.909070602406258
#
# ----
#
#
# On Iteration 216, step size is 0.0018185879518748393 and our updated position is -4.910889190358133
#
# ----
#
#
# On Iteration 217, step size is 0.0017822161928373603 and our updated position is -4.91267140655097
#
# ----
#
#
# On Iteration 218, step size is 0.0017465718689804177 and our updated position is -4.914417978419951
#
# ----
#
#
# On Iteration 219, step size is 0.0017116404316013245 and our updated position is -4.916129618851552
#
# ----
#
#
# On Iteration 220, step size is 0.0016774076229690849 and our updated position is -4.917807026474521
#
# ----
#
#
# On Iteration 221, step size is 0.00164385947050949 and our updated position is -4.9194508859450305
#
# ----
#
#
# On Iteration 222, step size is 0.00161098228109946 and our updated position is -4.92106186822613
#
# ----
#
#
# On Iteration 223, step size is 0.0015787626354777373 and our updated position is -4.922640630861608
#
# ----
#
#
# On Iteration 224, step size is 0.0015471873827674898 and our updated position is -4.924187818244375
#
# ----
#
#
# On Iteration 225, step size is 0.0015162436351126019 and our updated position is -4.925704061879488
#
# ----
#
#
# On Iteration 226, step size is 0.001485918762409888 and our updated position is -4.927189980641898
#
# ----
#
#
# On Iteration 227, step size is 0.0014562003871620988 and our updated position is -4.92864618102906
#
# ----
#
#
# On Iteration 228, step size is 0.0014270763794188568 and our updated position is -4.930073257408479
#
# ----
#
#
# On Iteration 229, step size is 0.0013985348518303908 and our updated position is -4.931471792260309
#
# ----
#
#
# On Iteration 230, step size is 0.001370564154793641 and our updated position is -4.932842356415103
#
# ----
#
#
# On Iteration 231, step size is 0.0013431528716978391 and our updated position is -4.9341855092868006
#
# ----
#
#
# On Iteration 232, step size is 0.0013162898142642376 and our updated position is -4.935501799101065
#
# ----
#
#
# On Iteration 233, step size is 0.001289964017979095 and our updated position is -4.936791763119044
#
# ----
#
#
# On Iteration 234, step size is 0.0012641647376190335 and our updated position is -4.938055927856663
#
# ----
#
#
# On Iteration 235, step size is 0.0012388814428669903 and our updated position is -4.93929480929953
#
# ----
#
#
# On Iteration 236, step size is 0.0012141038140089933 and our updated position is -4.940508913113539
#
# ----
#
#
# On Iteration 237, step size is 0.001189821737729524 and our updated position is -4.941698734851268
#
# ----
#
#
# On Iteration 238, step size is 0.0011660253029743828 and our updated position is -4.942864760154243
#
# ----
#
#
# On Iteration 239, step size is 0.0011427047969148063 and our updated position is -4.944007464951158
#
# ----
#
#
# On Iteration 240, step size is 0.0011198507009764214 and our updated position is -4.945127315652134
#
# ----
#
#
# On Iteration 241, step size is 0.0010974536869570173 and our updated position is -4.946224769339091
#
# ----
#
#
# On Iteration 242, step size is 0.0010755046132180368 and our updated position is -4.947300273952309
#
# ----
#
#
# On Iteration 243, step size is 0.0010539945209542267 and our updated position is -4.948354268473263
#
# ----
#
#
# On Iteration 244, step size is 0.0010329146305343428 and our updated position is -4.949387183103798
#
# ----
#
#
# On Iteration 245, step size is 0.0010122563379244554 and our updated position is -4.950399439441722
#
# ----
#
#
# On Iteration 246, step size is 0.0009920112111654333 and our updated position is -4.9513914506528875
#
# ----
#
#
# On Iteration 247, step size is 0.0009721709869419115 and our updated position is -4.9523636216398295
#
# ----
#
#
# On Iteration 248, step size is 0.0009527275672036595 and our updated position is -4.953316349207033
#
# ----
#
#
# On Iteration 249, step size is 0.0009336730158588935 and our updated position is -4.954250022222892
#
# ----
#
#
# On Iteration 250, step size is 0.0009149995555421953 and our updated position is -4.955165021778434
#
# ----
#
#
# On Iteration 251, step size is 0.0008966995644312803 and our updated position is -4.9560617213428655
#
# ----
#
#
# On Iteration 252, step size is 0.0008787655731428146 and our updated position is -4.956940486916008
#
# ----
#
#
# On Iteration 253, step size is 0.0008611902616797451 and our updated position is -4.957801677177688
#
# ----
#
#
# On Iteration 254, step size is 0.0008439664564461324 and our updated position is -4.958645643634134
#
# ----
#
#
# On Iteration 255, step size is 0.0008270871273170499 and our updated position is -4.959472730761451
#
# ----
#
#
# On Iteration 256, step size is 0.0008105453847706556 and our updated position is -4.960283276146222
#
# ----
#
#
# On Iteration 257, step size is 0.0007943344770753313 and our updated position is -4.961077610623297
#
# ----
#
#
# On Iteration 258, step size is 0.0007784477875336648 and our updated position is -4.961856058410831
#
# ----
#
#
# On Iteration 259, step size is 0.0007628788317832758 and our updated position is -4.962618937242614
#
# ----
#
#
# On Iteration 260, step size is 0.0007476212551473793 and our updated position is -4.9633665584977615
#
# ----
#
#
# On Iteration 261, step size is 0.0007326688300448581 and our updated position is -4.964099227327806
#
# ----
#
#
# On Iteration 262, step size is 0.0007180154534438543 and our updated position is -4.96481724278125
#
# ----
#
#
# On Iteration 263, step size is 0.0007036551443748706 and our updated position is -4.965520897925625
#
# ----
#
#
# On Iteration 264, step size is 0.000689582041487391 and our updated position is -4.9662104799671125
#
# ----
#
#
# On Iteration 265, step size is 0.0006757904006580162 and our updated position is -4.9668862703677705
#
# ----
#
#
# On Iteration 266, step size is 0.0006622745926447848 and our updated position is -4.967548544960415
#
# ----
#
#
# On Iteration 267, step size is 0.0006490291007921201 and our updated position is -4.968197574061207
#
# ----
#
#
# On Iteration 268, step size is 0.0006360485187757448 and our updated position is -4.968833622579983
#
# ----
#
#
# On Iteration 269, step size is 0.0006233275483999989 and our updated position is -4.969456950128383
#
# ----
#
#
# On Iteration 270, step size is 0.0006108609974324608 and our updated position is -4.970067811125816
#
# ----
#
#
# On Iteration 271, step size is 0.0005986437774838649 and our updated position is -4.9706664549032995
#
# ----
#
#
# On Iteration 272, step size is 0.0005866709019342053 and our updated position is -4.971253125805234
#
# ----
#
#
# On Iteration 273, step size is 0.0005749374838952548 and our updated position is -4.971828063289129
#
# ----
#
#
# On Iteration 274, step size is 0.0005634387342174918 and our updated position is -4.9723915020233465
#
# ----
#
#
# On Iteration 275, step size is 0.0005521699595334439 and our updated position is -4.97294367198288
#
# ----
#
#
# On Iteration 276, step size is 0.0005411265603427751 and our updated position is -4.973484798543223
#
# ----
#
#
# On Iteration 277, step size is 0.0005303040291355643 and our updated position is -4.974015102572358
#
# ----
#
#
# On Iteration 278, step size is 0.0005196979485528885 and our updated position is -4.974534800520911
#
# ----
#
#
# On Iteration 279, step size is 0.0005093039895820439 and our updated position is -4.975044104510493
#
# ----
#
#
# On Iteration 280, step size is 0.000499117909789959 and our updated position is -4.975543222420283
#
# ----
#
#
# On Iteration 281, step size is 0.0004891355515939111 and our updated position is -4.976032357971877
#
# ----
#
#
# On Iteration 282, step size is 0.00047935284056244143 and our updated position is -4.9765117108124395
#
# ----
#
#
# On Iteration 283, step size is 0.0004697657837509084 and our updated position is -4.97698147659619
#
# ----
#
#
# On Iteration 284, step size is 0.00046037046807612114 and our updated position is -4.9774418470642665
#
# ----
#
#
# On Iteration 285, step size is 0.000451163058714954 and our updated position is -4.9778930101229815
#
# ----
#
#
# On Iteration 286, step size is 0.0004421397975402641 and our updated position is -4.978335149920522
#
# ----
#
#
# On Iteration 287, step size is 0.000433297001589672 and our updated position is -4.978768446922111
#
# ----
#
#
# On Iteration 288, step size is 0.00042463106155743446 and our updated position is -4.979193077983669
#
# ----
#
#
# On Iteration 289, step size is 0.0004161384403262858 and our updated position is -4.979609216423995
#
# ----
#
#
# On Iteration 290, step size is 0.00040781567151970677 and our updated position is -4.980017032095515
#
# ----
#
#
# On Iteration 291, step size is 0.0003996593580897212 and our updated position is -4.9804166914536045
#
# ----
#
#
# On Iteration 292, step size is 0.00039166617092778466 and our updated position is -4.980808357624532
#
# ----
#
#
# On Iteration 293, step size is 0.00038383284750942437 and our updated position is -4.981192190472042
#
# ----
#
#
# On Iteration 294, step size is 0.00037615619055930694 and our updated position is -4.981568346662601
#
# ----
#
#
# On Iteration 295, step size is 0.00036863306674828067 and our updated position is -4.981936979729349
#
# ----
#
#
# On Iteration 296, step size is 0.0003612604054126223 and our updated position is -4.982298240134762
#
# ----
#
#
# On Iteration 297, step size is 0.00035403519730436983 and our updated position is -4.982652275332066
#
# ----
#
#
# On Iteration 298, step size is 0.0003469544933585311 and our updated position is -4.982999229825425
#
# ----
#
#
# On Iteration 299, step size is 0.00034001540349137827 and our updated position is -4.983339245228916
#
# ----
#
#
# On Iteration 300, step size is 0.0003332150954218349 and our updated position is -4.983672460324338
#
# ----
#
#
# On Iteration 301, step size is 0.00032655079351329164 and our updated position is -4.983999011117851
#
# ----
#
#
# On Iteration 302, step size is 0.00032001977764295475 and our updated position is -4.984319030895494
#
# ----
#
#
# On Iteration 303, step size is 0.00031361938208984697 and our updated position is -4.984632650277584
#
# ----
#
#
# On Iteration 304, step size is 0.00030734699444856517 and our updated position is -4.984939997272033
#
# ----
#
#
# On Iteration 305, step size is 0.00030120005455902543 and our updated position is -4.985241197326592
#
# ----
#
#
# On Iteration 306, step size is 0.00029517605346818243 and our updated position is -4.98553637338006
#
# ----
#
#
# On Iteration 307, step size is 0.0002892725323988543 and our updated position is -4.985825645912459
#
# ----
#
#
# On Iteration 308, step size is 0.00028348708175052195 and our updated position is -4.986109132994209
#
# ----
#
#
# On Iteration 309, step size is 0.0002778173401161155 and our updated position is -4.986386950334325
#
# ----
#
#
# On Iteration 310, step size is 0.00027226099331389975 and our updated position is -4.986659211327639
#
# ----
#
#
# On Iteration 311, step size is 0.00026681577344689344 and our updated position is -4.986926027101086
#
# ----
#
#
# On Iteration 312, step size is 0.0002614794579782753 and our updated position is -4.9871875065590645
#
# ----
#
#
# On Iteration 313, step size is 0.0002562498688183368 and our updated position is -4.987443756427883
#
# ----
#
#
# On Iteration 314, step size is 0.0002511248714425207 and our updated position is -4.987694881299325
#
# ----
#
#
# On Iteration 315, step size is 0.0002461023740139012 and our updated position is -4.987940983673339
#
# ----
#
#
# On Iteration 316, step size is 0.00024118032653319688 and our updated position is -4.9881821639998725
#
# ----
#
#
# On Iteration 317, step size is 0.0002363567200029948 and our updated position is -4.9884185207198755
#
# ----
#
#
# On Iteration 318, step size is 0.00023162958560263291 and our updated position is -4.988650150305478
#
# ----
#
#
# On Iteration 319, step size is 0.00022699699389061578 and our updated position is -4.988877147299369
#
# ----
#
#
# On Iteration 320, step size is 0.00022245705401235938 and our updated position is -4.989099604353381
#
# ----
#
#
# On Iteration 321, step size is 0.00021800791293280497 and our updated position is -4.989317612266314
#
# ----
#
#
# On Iteration 322, step size is 0.00021364775467347386 and our updated position is -4.989531260020987
#
# ----
#
#
# On Iteration 323, step size is 0.00020937479958060834 and our updated position is -4.989740634820568
#
# ----
#
#
# On Iteration 324, step size is 0.00020518730358887183 and our updated position is -4.989945822124157
#
# ----
#
#
# On Iteration 325, step size is 0.00020108355751702334 and our updated position is -4.990146905681674
#
# ----
#
#
# On Iteration 326, step size is 0.00019706188636625654 and our updated position is -4.99034396756804
#
# ----
#
#
# On Iteration 327, step size is 0.00019312064863896694 and our updated position is -4.990537088216679
#
# ----
#
#
# On Iteration 328, step size is 0.00018925823566640076 and our updated position is -4.9907263464523455
#
# ----
#
#
# On Iteration 329, step size is 0.00018547307095317933 and our updated position is -4.990911819523299
#
# ----
#
#
# On Iteration 330, step size is 0.00018176360953425785 and our updated position is -4.991093583132833
#
# ----
#
#
# On Iteration 331, step size is 0.0001781283373434306 and our updated position is -4.991271711470176
#
# ----
#
#
# On Iteration 332, step size is 0.00017456577059604683 and our updated position is -4.991446277240772
#
# ----
#
#
# On Iteration 333, step size is 0.00017107445518416142 and our updated position is -4.9916173516959566
#
# ----
#
#
# On Iteration 334, step size is 0.000167652966080567 and our updated position is -4.991785004662037
#
# ----
#
#
# On Iteration 335, step size is 0.00016429990675970174 and our updated position is -4.991949304568797
#
# ----
#
#
# On Iteration 336, step size is 0.00016101390862388598 and our updated position is -4.992110318477421
#
# ----
#
#
# On Iteration 337, step size is 0.00015779363045176353 and our updated position is -4.9922681121078725
#
# ----
#
#
# On Iteration 338, step size is 0.00015463775784230194 and our updated position is -4.992422749865715
#
# ----
#
#
# On Iteration 339, step size is 0.00015154500268543813 and our updated position is -4.9925742948684
#
# ----
#
#
# On Iteration 340, step size is 0.00014851410263183595 and our updated position is -4.992722808971032
#
# ----
#
#
# On Iteration 341, step size is 0.00014554382057951898 and our updated position is -4.992868352791612
#
# ----
#
#
# On Iteration 342, step size is 0.00014263294416760885 and our updated position is -4.993010985735779
#
# ----
#
#
# On Iteration 343, step size is 0.00013978028528427444 and our updated position is -4.9931507660210634
#
# ----
#
#
# On Iteration 344, step size is 0.00013698467957912186 and our updated position is -4.993287750700643
#
# ----
#
#
# On Iteration 345, step size is 0.00013424498598713086 and our updated position is -4.99342199568663
#
# ----
#
#
# On Iteration 346, step size is 0.00013156008626769022 and our updated position is -4.993553555772897
#
# ----
#
#
# On Iteration 347, step size is 0.0001289288845418568 and our updated position is -4.993682484657439
#
# ----
#
#
# On Iteration 348, step size is 0.00012635030685093085 and our updated position is -4.99380883496429
#
# ----
#
#
# On Iteration 349, step size is 0.00012382330071414316 and our updated position is -4.993932658265004
#
# ----
#
#
# On Iteration 350, step size is 0.0001213468346996649 and our updated position is -4.994054005099704
#
# ----
#
#
# On Iteration 351, step size is 0.00011891989800627556 and our updated position is -4.99417292499771
#
# ----
#
#
# On Iteration 352, step size is 0.00011654150004591912 and our updated position is -4.994289466497756
#
# ----
#
#
# On Iteration 353, step size is 0.00011421067004491192 and our updated position is -4.994403677167801
#
# ----
#
#
# On Iteration 354, step size is 0.00011192645664426237 and our updated position is -4.994515603624445
#
# ----
#
#
# On Iteration 355, step size is 0.000109687927511537 and our updated position is -4.994625291551957
#
# ----
#
#
# On Iteration 356, step size is 0.00010749416896072006 and our updated position is -4.994732785720918
#
# ----
#
#
# On Iteration 357, step size is 0.00010534428558184317 and our updated position is -4.9948381300064995
#
# ----
#
#
# On Iteration 358, step size is 0.00010323739986972669 and our updated position is -4.994941367406369
#
# ----
#
#
# On Iteration 359, step size is 0.0001011726518722611 and our updated position is -4.995042540058241
#
# ----
#
#
# On Iteration 360, step size is 9.914919883513562e-05 and our updated position is -4.995141689257077
#
# ----
#
#
# On Iteration 361, step size is 9.716621485811316e-05 and our updated position is -4.995238855471935
#
# ----
#
#
# On Iteration 362, step size is 9.522289056107525e-05 and our updated position is -4.995334078362496
#
# ----
#
#
# On Iteration 363, step size is 9.33184327500669e-05 and our updated position is -4.995427396795246
#
# ----
#
#
# On Iteration 364, step size is 9.145206409488793e-05 and our updated position is -4.995518848859341
#
# ----
#
#
# On Iteration 365, step size is 8.962302281290135e-05 and our updated position is -4.995608471882154
#
# ----
#
#
# On Iteration 366, step size is 8.783056235728282e-05 and our updated position is -4.995696302444511
#
# ----
#
#
# On Iteration 367, step size is 8.607395110971083e-05 and our updated position is -4.995782376395621
#
# ----
#
#
# On Iteration 368, step size is 8.435247208726793e-05 and our updated position is -4.995866728867708
#
# ----
#
#
# On Iteration 369, step size is 8.266542264578902e-05 and our updated position is -4.995949394290354
#
# ----
#
#
# On Iteration 370, step size is 8.101211419297982e-05 and our updated position is -4.996030406404547
#
# ----
#
#
# On Iteration 371, step size is 7.939187190864061e-05 and our updated position is -4.996109798276455
#
# ----
#
#
# On Iteration 372, step size is 7.780403447110729e-05 and our updated position is -4.996187602310926
#
# ----
#
#
# On Iteration 373, step size is 7.624795378102789e-05 and our updated position is -4.996263850264707
#
# ----
#
#
# On Iteration 374, step size is 7.47229947055672e-05 and our updated position is -4.996338573259413
#
# ----
#
#
# On Iteration 375, step size is 7.322853481195324e-05 and our updated position is -4.996411801794225
#
# ----
#
#
# On Iteration 376, step size is 7.176396411523456e-05 and our updated position is -4.99648356575834
#
# ----
#
#
# On Iteration 377, step size is 7.032868483314303e-05 and our updated position is -4.996553894443173
#
# ----
#
#
# On Iteration 378, step size is 6.89221111365157e-05 and our updated position is -4.99662281655431
#
# ----
#
#
# On Iteration 379, step size is 6.754366891392749e-05 and our updated position is -4.996690360223224
#
# ----
#
#
# On Iteration 380, step size is 6.619279553543578e-05 and our updated position is -4.996756553018759
#
# ----
#
#
# On Iteration 381, step size is 6.486893962520668e-05 and our updated position is -4.996821421958384
#
# ----
#
#
# On Iteration 382, step size is 6.357156083236504e-05 and our updated position is -4.996884993519217
#
# ----
#
#
# On Iteration 383, step size is 6.230012961605524e-05 and our updated position is -4.996947293648833
#
# ----
#
#
# On Iteration 384, step size is 6.105412702339663e-05 and our updated position is -4.997008347775856
#
# ----
#
#
# On Iteration 385, step size is 5.98330444825379e-05 and our updated position is -4.997068180820339
#
# ----
#
#
# On Iteration 386, step size is 5.8636383593047015e-05 and our updated position is -4.997126817203932
#
# ----
#
#
# On Iteration 387, step size is 5.7463655921630163e-05 and our updated position is -4.9971842808598534
#
# ----
#
#
# On Iteration 388, step size is 5.6314382803179797e-05 and our updated position is -4.997240595242657
#
# ----
#
#
# On Iteration 389, step size is 5.518809514715173e-05 and our updated position is -4.997295783337804
#
# ----
#
#
# On Iteration 390, step size is 5.408433324394224e-05 and our updated position is -4.997349867671048
#
# ----
#
#
# On Iteration 391, step size is 5.3002646579258794e-05 and our updated position is -4.997402870317627
#
# ----
#
#
# On Iteration 392, step size is 5.1942593647602564e-05 and our updated position is -4.997454812911275
#
# ----
#
#
# On Iteration 393, step size is 5.090374177463275e-05 and our updated position is -4.997505716653049
#
# ----
#
#
# On Iteration 394, step size is 4.9885666938642714e-05 and our updated position is -4.997555602319988
#
# ----
#
#
# On Iteration 395, step size is 4.888795360002973e-05 and our updated position is -4.997604490273588
#
# ----
#
#
# On Iteration 396, step size is 4.791019452810019e-05 and our updated position is -4.997652400468116
#
# ----
#
#
# On Iteration 397, step size is 4.695199063764477e-05 and our updated position is -4.997699352458754
#
# ----
#
#
# On Iteration 398, step size is 4.601295082462542e-05 and our updated position is -4.997745365409578
#
# ----
#
#
# On Iteration 399, step size is 4.509269180807962e-05 and our updated position is -4.997790458101386
#
# ----
#
#
# On Iteration 400, step size is 4.419083797202461e-05 and our updated position is -4.997834648939358
#
# ----
#
#
# On Iteration 401, step size is 4.33070212126907e-05 and our updated position is -4.997877955960571
#
# ----
#
#
# On Iteration 402, step size is 4.244088078841912e-05 and our updated position is -4.9979203968413595
#
# ----
#
#
# On Iteration 403, step size is 4.159206317311259e-05 and our updated position is -4.997961988904533
#
# ----
#
#
# On Iteration 404, step size is 4.076022190968587e-05 and our updated position is -4.998002749126442
#
# ----
#
#
# On Iteration 405, step size is 3.9945017471509914e-05 and our updated position is -4.998042694143914
#
# ----
#
#
# On Iteration 406, step size is 3.9146117122079716e-05 and our updated position is -4.998081840261036
#
# ----
#
#
# On Iteration 407, step size is 3.836319477912298e-05 and our updated position is -4.998120203455815
#
# ----
#
#
# On Iteration 408, step size is 3.75959308840379e-05 and our updated position is -4.998157799386699
#
# ----
#
#
# On Iteration 409, step size is 3.684401226600187e-05 and our updated position is -4.998194643398965
#
# ----
#
#
# On Iteration 410, step size is 3.610713202029103e-05 and our updated position is -4.998230750530985
#
# ----
#
#
# On Iteration 411, step size is 3.538498938038259e-05 and our updated position is -4.998266135520366
#
# ----
#
#
# On Iteration 412, step size is 3.467728959272165e-05 and our updated position is -4.998300812809958
#
# ----
#
#
# On Iteration 413, step size is 3.3983743801258015e-05 and our updated position is -4.99833479655376
#
# ----
#
#
# On Iteration 414, step size is 3.3304068924877583e-05 and our updated position is -4.9983681006226846
#
# ----
#
#
# On Iteration 415, step size is 3.263798754638003e-05 and our updated position is -4.998400738610231
#
# ----
#
#
# On Iteration 416, step size is 3.198522779523927e-05 and our updated position is -4.998432723838026
#
# ----
#
#
# On Iteration 417, step size is 3.1345523239245665e-05 and our updated position is -4.998464069361265
#
# ----
#
#
# On Iteration 418, step size is 3.0718612774371934e-05 and our updated position is -4.99849478797404
#
# ----
#
#
# On Iteration 419, step size is 3.0104240519079895e-05 and our updated position is -4.998524892214559
#
# ----
#
#
# On Iteration 420, step size is 2.9502155708627242e-05 and our updated position is -4.9985543943702675
#
# ----
#
#
# On Iteration 421, step size is 2.8912112594703387e-05 and our updated position is -4.998583306482862
#
# ----
#
#
# On Iteration 422, step size is 2.8333870342400758e-05 and our updated position is -4.998611640353205
#
# ----
#
#
# On Iteration 423, step size is 2.7767192936067886e-05 and our updated position is -4.998639407546141
#
# ----
#
#
# On Iteration 424, step size is 2.7211849077168893e-05 and our updated position is -4.998666619395218
#
# ----
#
#
# On Iteration 425, step size is 2.6667612095465643e-05 and our updated position is -4.998693287007313
#
# ----
#
#
# On Iteration 426, step size is 2.6134259853982655e-05 and our updated position is -4.998719421267167
#
# ----
#
#
# On Iteration 427, step size is 2.561157465663655e-05 and our updated position is -4.998745032841824
#
# ----
#
#
# On Iteration 428, step size is 2.509934316385909e-05 and our updated position is -4.998770132184988
#
# ----
#
#
# On Iteration 429, step size is 2.4597356300226636e-05 and our updated position is -4.998794729541288
#
# ----
#
#
# On Iteration 430, step size is 2.4105409174524084e-05 and our updated position is -4.9988188349504625
#
# ----
#
#
# On Iteration 431, step size is 2.362330099092702e-05 and our updated position is -4.9988424582514535
#
# ----
#
#
# On Iteration 432, step size is 2.3150834970842027e-05 and our updated position is -4.998865609086424
#
# ----
#
#
# On Iteration 433, step size is 2.268781827119426e-05 and our updated position is -4.9988882969046955
#
# ----
#
#
# On Iteration 434, step size is 2.2234061906267755e-05 and our updated position is -4.998910530966602
#
# ----
#
#
# On Iteration 435, step size is 2.1789380667769365e-05 and our updated position is -4.9989323203472695
#
# ----
#
#
# On Iteration 436, step size is 2.1353593054662667e-05 and our updated position is -4.998953673940324
#
# ----
#
#
# On Iteration 437, step size is 2.0926521193231906e-05 and our updated position is -4.998974600461517
#
# ----
#
#
# On Iteration 438, step size is 2.050799076958043e-05 and our updated position is -4.998995108452287
#
# ----
#
#
# On Iteration 439, step size is 2.009783095413553e-05 and our updated position is -4.999015206283241
#
# ----
#
#
# On Iteration 440, step size is 1.9695874335035057e-05 and our updated position is -4.999034902157576
#
# ----
#
#
# On Iteration 441, step size is 1.93019568488495e-05 and our updated position is -4.999054204114425
#
# ----
#
#
# On Iteration 442, step size is 1.8915917711304076e-05 and our updated position is -4.999073120032136
#
# ----
#
#
# On Iteration 443, step size is 1.8537599356882595e-05 and our updated position is -4.999091657631493
#
# ----
#
#
# On Iteration 444, step size is 1.8166847370437722e-05 and our updated position is -4.999109824478864
#
# ----
#
#
# On Iteration 445, step size is 1.7803510422353952e-05 and our updated position is -4.999127627989286
#
# ----
#
#
# On Iteration 446, step size is 1.7447440214368726e-05 and our updated position is -4.9991450754295
#
# ----
#
#
# On Iteration 447, step size is 1.7098491410294514e-05 and our updated position is -4.999162173920911
#
# ----
#
#
# On Iteration 448, step size is 1.6756521581839934e-05 and our updated position is -4.9991789304424925
#
# ----
#
#
# On Iteration 449, step size is 1.6421391149989972e-05 and our updated position is -4.9991953518336425
#
# ----
#
#
# On Iteration 450, step size is 1.609296332727439e-05 and our updated position is -4.99921144479697
#
# ----
#
#
# On Iteration 451, step size is 1.57711040609243e-05 and our updated position is -4.999227215901031
#
# ----
#
#
# On Iteration 452, step size is 1.545568197958147e-05 and our updated position is -4.99924267158301
#
# ----
#
#
# On Iteration 453, step size is 1.5146568340007605e-05 and our updated position is -4.99925781815135
#
# ----
#
#
# On Iteration 454, step size is 1.4843636972905472e-05 and our updated position is -4.999272661788323
#
# ----
#
#
# On Iteration 455, step size is 1.4546764233180909e-05 and our updated position is -4.999287208552556
#
# ----
#
#
# On Iteration 456, step size is 1.4255828948428473e-05 and our updated position is -4.999301464381505
#
# ----
#
#
# On Iteration 457, step size is 1.3970712370081628e-05 and our updated position is -4.999315435093875
#
# ----
#
#
# On Iteration 458, step size is 1.3691298122786577e-05 and our updated position is -4.999329126391998
#
# ----
#
#
# On Iteration 459, step size is 1.3417472159993338e-05 and our updated position is -4.999342543864158
#
# ----
#
#
# On Iteration 460, step size is 1.3149122716882289e-05 and our updated position is -4.9993556929868745
#
# ----
#
#
# On Iteration 461, step size is 1.2886140262402535e-05 and our updated position is -4.999368579127137
#
# ----
#
#
# On Iteration 462, step size is 1.2628417457527519e-05 and our updated position is -4.9993812075445945
#
# ----
#
#
# On Iteration 463, step size is 1.2375849108181569e-05 and our updated position is -4.999393583393703
#
# ----
#
#
# On Iteration 464, step size is 1.2128332126160046e-05 and our updated position is -4.999405711725829
#
# ----
#
#
# On Iteration 465, step size is 1.1885765483832245e-05 and our updated position is -4.999417597491313
#
# ----
#
#
# On Iteration 466, step size is 1.1648050174173363e-05 and our updated position is -4.999429245541487
#
# ----
#
#
# On Iteration 467, step size is 1.1415089169908299e-05 and our updated position is -4.999440660630657
#
# ----
#
#
# On Iteration 468, step size is 1.118678738709633e-05 and our updated position is -4.999451847418044
#
# ----
#
#
# On Iteration 469, step size is 1.0963051638945842e-05 and our updated position is -4.999462810469683
#
# ----
#
#
# On Iteration 470, step size is 1.0743790606504433e-05 and our updated position is -4.999473554260289
#
# ----
#
#
# On Iteration 471, step size is 1.052891479425e-05 and our updated position is -4.9994840831750835
#
# ----
#
#
# On Iteration 472, step size is 1.031833649811631e-05 and our updated position is -4.999494401511582
#
# ----
#
#
# On Iteration 473, step size is 1.011196976818951e-05 and our updated position is -4.99950451348135
#
# ----
#
#
# On Iteration 474, step size is 9.909730373180992e-06 and our updated position is -4.999514423211723
#
# ----
#
#
# On Iteration 475, step size is 9.711535765788426e-06 and our updated position is -4.999524134747489
#
# ----
#
#
# On Iteration 476, step size is 9.517305049833169e-06 and our updated position is -4.999533652052539
#
# ----
#
#
# On Iteration 477, step size is 9.326958949174013e-06 and our updated position is -4.999542979011488
#
# ----
#
#
# On Iteration 478, step size is 9.140419770403696e-06 and our updated position is -4.999552119431258
#
# ----
#
#
# On Iteration 479, step size is 8.957611374427188e-06 and our updated position is -4.999561077042633
#
# ----
#
#
# On Iteration 480, step size is 8.778459147151807e-06 and our updated position is -4.99956985550178
#
# ----
#
#
# On Iteration 481, step size is 8.602889963960081e-06 and our updated position is -4.999578458391744
#
# ----
#
#
# On Iteration 482, step size is 8.430832164840751e-06 and our updated position is -4.999586889223909
#
# ----
#
#
# On Iteration 483, step size is 8.262215521526173e-06 and our updated position is -4.99959515143943
#
# ----
#
#
# On Iteration 484, step size is 8.096971211735138e-06 and our updated position is -4.999603248410642
#
# ----
#
#
# On Iteration 485, step size is 7.935031787198454e-06 and our updated position is -4.999611183442429
#
# ----
#
#
# On Iteration 486, step size is 7.776331151454485e-06 and our updated position is -4.9996189597735805
#
# ----
#
#
# On Iteration 487, step size is 7.620804528762903e-06 and our updated position is -4.999626580578109
#
# ----
#
#
# On Iteration 488, step size is 7.468388437459339e-06 and our updated position is -4.999634048966547
#
# ----
#
#
# On Iteration 489, step size is 7.319020668639098e-06 and our updated position is -4.999641367987215
#
# ----
#
#
# On Iteration 490, step size is 7.172640255959095e-06 and our updated position is -4.999648540627471
#
# ----
#
#
# On Iteration 491, step size is 7.029187450768859e-06 and our updated position is -4.999655569814922
#
# ----
#
#
# On Iteration 492, step size is 6.8886037016824275e-06 and our updated position is -4.999662458418624
#
# ----
#
#
# On Iteration 493, step size is 6.750831627932996e-06 and our updated position is -4.999669209250252
#
# ----
#
#
# On Iteration 494, step size is 6.6158149953921e-06 and our updated position is -4.999675825065247
#
# ----
#
#
# On Iteration 495, step size is 6.483498695253331e-06 and our updated position is -4.999682308563942
#
# ----
#
#
# On Iteration 496, step size is 6.353828720939703e-06 and our updated position is -4.999688662392663
#
# ----
#
#
# On Iteration 497, step size is 6.226752146787362e-06 and our updated position is -4.99969488914481
#
# ----
#
#
# On Iteration 498, step size is 6.102217104064778e-06 and our updated position is -4.999700991361914
#
# ----
#
#
# On Iteration 499, step size is 5.9801727614328115e-06 and our updated position is -4.999706971534676
#
# ----
#
#
# On Iteration 500, step size is 5.860569306292973e-06 and our updated position is -4.999712832103982
#
# ----
#
#
# On Iteration 501, step size is 5.743357919918424e-06 and our updated position is -4.999718575461902
#
# ----
#
#
# On Iteration 502, step size is 5.628490762354943e-06 and our updated position is -4.999724203952664
#
# ----
#
#
# On Iteration 503, step size is 5.515920946663755e-06 and our updated position is -4.999729719873611
#
# ----
#
#
# On Iteration 504, step size is 5.405602527375208e-06 and our updated position is -4.999735125476138
#
# ----
#
#
# On Iteration 505, step size is 5.2974904773961384e-06 and our updated position is -4.999740422966616
#
# ----
#
#
# On Iteration 506, step size is 5.191540667581762e-06 and our updated position is -4.999745614507283
#
# ----
#
#
# On Iteration 507, step size is 5.087709854301181e-06 and our updated position is -4.9997507022171375
#
# ----
#
#
# On Iteration 508, step size is 4.985955657232921e-06 and our updated position is -4.999755688172795
#
# ----
#
#
# On Iteration 509, step size is 4.886236544265898e-06 and our updated position is -4.999760574409339
#
# ----
#
#
# On Iteration 510, step size is 4.788511812847673e-06 and our updated position is -4.999765362921152
#
# ----
#
#
# On Iteration 511, step size is 4.692741576661774e-06 and our updated position is -4.9997700556627285
#
# ----
#
#
# On Iteration 512, step size is 4.598886745199593e-06 and our updated position is -4.999774654549474
#
# ----
#
#
# On Iteration 513, step size is 4.50690901043771e-06 and our updated position is -4.999779161458484
#
# ----
#
#
# On Iteration 514, step size is 4.416770829962502e-06 and our updated position is -4.999783578229314
#
# ----
#
#
# On Iteration 515, step size is 4.328435413647469e-06 and our updated position is -4.999787906664728
#
# ----
#
#
# On Iteration 516, step size is 4.241866705889663e-06 and our updated position is -4.999792148531434
#
# ----
#
#
# On Iteration 517, step size is 4.157029371398835e-06 and our updated position is -4.999796305560805
#
# ----
#
#
# On Iteration 518, step size is 4.073888783651114e-06 and our updated position is -4.999800379449589
#
# ----
#
#
# On Iteration 519, step size is 3.992411008013619e-06 and our updated position is -4.999804371860597
#
# ----
#
#
# On Iteration 520, step size is 3.912562788421781e-06 and our updated position is -4.999808284423385
#
# ----
#
#
# On Iteration 521, step size is 3.83431153228031e-06 and our updated position is -4.999812118734917
#
# ----
#
#
# On Iteration 522, step size is 3.757625301581413e-06 and our updated position is -4.999815876360219
#
# ----
#
#
# On Iteration 523, step size is 3.6824727960294013e-06 and our updated position is -4.999819558833015
#
# ----
#
#
# On Iteration 524, step size is 3.6088233397180147e-06 and our updated position is -4.999823167656355
#
# ----
#
#
# On Iteration 525, step size is 3.5366468731368172e-06 and our updated position is -4.999826704303228
#
# ----
#
#
# On Iteration 526, step size is 3.4659139354076274e-06 and our updated position is -4.999830170217163
#
# ----
#
#
# On Iteration 527, step size is 3.3965956562909128e-06 and our updated position is -4.9998335668128195
#
# ----
#
#
# On Iteration 528, step size is 3.3286637437512923e-06 and our updated position is -4.999836895476563
#
# ----
#
#
# On Iteration 529, step size is 3.262090468858503e-06 and our updated position is -4.999840157567032
#
# ----
#
#
# On Iteration 530, step size is 3.1968486595701506e-06 and our updated position is -4.999843354415692
#
# ----
#
#
# On Iteration 531, step size is 3.132911686520856e-06 and our updated position is -4.999846487327378
#
# ----
#
#
# On Iteration 532, step size is 3.0702534523641134e-06 and our updated position is -4.999849557580831
#
# ----
#
#
# On Iteration 533, step size is 3.008848383778684e-06 and our updated position is -4.999852566429214
#
# ----
#
#
# On Iteration 534, step size is 2.9486714154813853e-06 and our updated position is -4.99985551510063
#
# ----
#
#
# On Iteration 535, step size is 2.889697987562556e-06 and our updated position is -4.999858404798617
#
# ----
#
#
# On Iteration 536, step size is 2.831904027722487e-06 and our updated position is -4.999861236702645
#
# ----
#
#
# On Iteration 537, step size is 2.7752659468305296e-06 and our updated position is -4.999864011968592
#
# ----
#
#
# On Iteration 538, step size is 2.719760628266954e-06 and our updated position is -4.99986673172922
#
# ----
#
#
# On Iteration 539, step size is 2.665365415488452e-06 and our updated position is -4.999869397094636
#
# ----
#
#
# On Iteration 540, step size is 2.612058107587245e-06 and our updated position is -4.999872009152743
#
# ----
#
#
# On Iteration 541, step size is 2.559816945080229e-06 and our updated position is -4.999874568969688
#
# ----
#
#
# On Iteration 542, step size is 2.50862060635626e-06 and our updated position is -4.999877077590295
#
# ----
#
#
# On Iteration 543, step size is 2.4584481943534797e-06 and our updated position is -4.999879536038489
#
# ----
#
#
# On Iteration 544, step size is 2.409279230342065e-06 and our updated position is -4.9998819453177195
#
# ----
#
#
# On Iteration 545, step size is 2.361093645930623e-06 and our updated position is -4.999884306411365
#
# ----
#
#
# On Iteration 546, step size is 2.3138717724080493e-06 and our updated position is -4.999886620283138
#
# ----
#
#
# On Iteration 547, step size is 2.2675943371908147e-06 and our updated position is -4.999888887877475
#
# ----
#
#
# On Iteration 548, step size is 2.222242450500289e-06 and our updated position is -4.9998911101199255
#
# ----
#
#
# On Iteration 549, step size is 2.1777976018100276e-06 and our updated position is -4.999893287917527
#
# ----
#
#
# On Iteration 550, step size is 2.1342416491876293e-06 and our updated position is -4.9998954221591765
#
# ----
#
#
# On Iteration 551, step size is 2.0915568166302023e-06 and our updated position is -4.999897513715993
#
# ----
#
#
# On Iteration 552, step size is 2.049725679853509e-06 and our updated position is -4.999899563441673
#
# ----
#
#
# On Iteration 553, step size is 2.008731166291966e-06 and our updated position is -4.999901572172839
#
# ----
#
#
# On Iteration 554, step size is 1.9685565435523245e-06 and our updated position is -4.999903540729383
#
# ----
#
#
# On Iteration 555, step size is 1.929185412308243e-06 and our updated position is -4.999905469914795
#
# ----
#
#
# On Iteration 556, step size is 1.890601704523931e-06 and our updated position is -4.9999073605165
#
# ----
#
#
# On Iteration 557, step size is 1.8527896701314717e-06 and our updated position is -4.99990921330617
#
# ----
#
#
# On Iteration 558, step size is 1.815733877030823e-06 and our updated position is -4.999911029040047
#
# ----
#
#
# On Iteration 559, step size is 1.7794191986553187e-06 and our updated position is -4.9999128084592455
#
# ----
#
#
# On Iteration 560, step size is 1.743830814859848e-06 and our updated position is -4.99991455229006
#
# ----
#
#
# On Iteration 561, step size is 1.7089541985981782e-06 and our updated position is -4.999916261244259
#
# ----
#
#
# On Iteration 562, step size is 1.6747751150347767e-06 and our updated position is -4.999917936019374
#
# ----
#
#
# On Iteration 563, step size is 1.641279612663027e-06 and our updated position is -4.999919577298987
#
# ----
#
#
# On Iteration 564, step size is 1.6084540206406928e-06 and our updated position is -4.999921185753007
#
# ----
#
#
# On Iteration 565, step size is 1.5762849399081347e-06 and our updated position is -4.999922762037947
#
# ----
#
#
# On Iteration 566, step size is 1.5447592414119526e-06 and our updated position is -4.999924306797189
#
# ----
#
#
# On Iteration 567, step size is 1.5138640563350236e-06 and our updated position is -4.999925820661245
#
# ----
#
#
# On Iteration 568, step size is 1.4835867752083232e-06 and our updated position is -4.99992730424802
#
# ----
#
#
# On Iteration 569, step size is 1.4539150399173195e-06 and our updated position is -4.99992875816306
#
# ----
#
#
# On Iteration 570, step size is 1.4248367383729033e-06 and our updated position is -4.999930182999798
#
# ----
#
#
# On Iteration 571, step size is 1.3963400036232088e-06 and our updated position is -4.999931579339802
#
# ----
#
#
# On Iteration 572, step size is 1.3684132040836516e-06 and our updated position is -4.999932947753006
#
# ----
#
#
# On Iteration 573, step size is 1.341044939984215e-06 and our updated position is -4.999934288797946
#
# ----
#
#
# On Iteration 574, step size is 1.3142240407049144e-06 and our updated position is -4.999935603021987
#
# ----
#
#
# On Iteration 575, step size is 1.2879395603349053e-06 and our updated position is -4.999936890961547
#
# ----
#
#
# On Iteration 576, step size is 1.2621807687906994e-06 and our updated position is -4.999938153142316
#
# ----
#
#
# On Iteration 577, step size is 1.236937153592521e-06 and our updated position is -4.9999393900794695
#
# ----
#
#
# On Iteration 578, step size is 1.2121984109825235e-06 and our updated position is -4.9999406022778805
#
# ----
#
#
# On Iteration 579, step size is 1.1879544423720745e-06 and our updated position is -4.999941790232323
#
# ----
#
#
# On Iteration 580, step size is 1.1641953534535787e-06 and our updated position is -4.999942954427676
#
# ----
#
#
# On Iteration 581, step size is 1.1409114462068715e-06 and our updated position is -4.9999440953391225
#
# ----
#
#
# On Iteration 582, step size is 1.118093217122862e-06 and our updated position is -4.99994521343234
#
# ----
#
#
# On Iteration 583, step size is 1.0957313536508195e-06 and our updated position is -4.999946309163693
#
# ----
#
#
# On Iteration 584, step size is 1.0738167262047682e-06 and our updated position is -4.9999473829804195
#
# ----
#
#
# On Iteration 585, step size is 1.0523403917162e-06 and our updated position is -4.999948435320811
#
# ----
#
#
# On Iteration 586, step size is 1.0312935838641124e-06 and our updated position is -4.999949466614395
#
# ----
#
#
# On Iteration 587, step size is 1.0106677121868302e-06 and our updated position is -4.999950477282107
#
# ----
#
#
# On Iteration 588, step size is 9.904543576411129e-07 and our updated position is -4.999951467736465
#
# ----

# %% [markdown]
# ### And we're here!

# %%
print("The Local Minima occurs at {}".format(current_position))
# Out:
# The Local Minima occurs at -4.999951467736465

# %% [markdown]
# ## Now that we know how Gradient Descent works, let us create our own user defined function called _gradientdescent()_ and get the values of x's and y's along the descent slope of another graph.

# %% [markdown]
# ### This time I am taking the function y = x<sup>2</sup>-4x+2

# %%
def fx(x):
    y = x**2 - 4*x + 2

    return y

# Testing

fx(2)
# Out:
# -2

# %% [markdown]
# ## How to : gradientdescent()

# %%
# Importing pandas to save our x and y values as columns in a dataframe

import pandas as pd

def gradientdescent(prev_position,alpha,max_iters):
    # These are lists that will eventually have our x and y values
    
    gd_x = []
    gd_y = []
    result = []
    
    # Appending position with respec to x
    gd_x.append(prev_position)
    
    # And y
    gd_y.append(fx(prev_position))
    
    # Defining the derivative which is our GRADIENT
    df = lambda x: 2*x-4
    
    # Updating x's and y's from here
    for i in range(max_iters):
        current_position = prev_position - alpha*(df(prev_position))
        gd_x.append(current_position)
        gd_y.append(fx(current_position))
        
        # Updating previous position
        prev_position = current_position
        
        # Adding our descent to a pandas dataframe to make the view neat
        result = pd.DataFrame({"X":gd_x})
        result["Y"] = pd.DataFrame(gd_y)
    
    # UNCOMMENT TO CHECK LOCAL MINIMA
    
    print("Local Minima is at\n{}".format(result[["X","Y"]].min(axis=0)))
    
    return gd_x,gd_y

# %% [markdown]
# ### I am starting at a point 0.7, and setting my alpha to 0.15 and making 10 iterations down the slope and here's what my Gradient Descent looks like :

# %%
gradientdescent(0.7,0.15,10)
# Out:
# Local Minima is at
# X    0.700000
# Y   -1.998652
# dtype: float64
# ([0.7,
#   1.0899999999999999,
#   1.363,
#   1.5541,
#   1.68787,
#   1.781509,
#   1.8470563,
#   1.8929394099999999,
#   1.925057587,
#   1.9475403109,
#   1.96327821763],
#  [-0.31000000000000005,
#   -1.1719,
#   -1.5942309999999997,
#   -1.80117319,
#   -1.9025748631,
#   -1.952261682919,
#   -1.97660822463031,
#   -1.988538030068852,
#   -1.9943836347337376,
#   -1.9972479810195312,
#   -1.9986515106995704])

# %% [markdown]
# # Let's make some visualizations!

# %%
# Initializing with the different values 

prev_position = 4
alpha = 0.05
max_iters = 50

# %% [markdown]
# ## Plotting GD :

# %%
# Taking a new range for x

x = np.arange(-1, 5, 0.01)
y = fx(x)

plt.rcParams['figure.figsize'] = [13,6]
fig, ax = plt.subplots(sharey = True)

# Setting x and y axes' parameters

ax.plot(x, y, lw = 0.9, color = 'k')
ax.set_xlim([min(x), max(x)])
ax.set_ylim([-3, max(y)+1])
ax.set_xlabel(r'$x$')
ax.set_ylabel(r'$y$')

# Running our user-defined function to get input for the plot

gd_x, gd_y = gradientdescent(prev_position, alpha, max_iters)

# Making a scatterplot of points along the curve

ax.scatter(gd_x, gd_y, c = 'b')

# Plotting the Descent

for i in range(1, max_iters+1):
    ax.annotate('', xy=(gd_x[i], gd_y[i]), xytext=(gd_x[i-1], gd_y[i-1]),
                   arrowprops={'arrowstyle': '->', 'color': 'r', 'lw': 1},
                   va='center', ha='center')

plt.show()
# Out:
# Local Minima is at
# X    2.010308
# Y   -1.999894
# dtype: float64

# %% [markdown]
# # Let's animate GD !

# %%
from matplotlib import animation

plt.rcParams['figure.figsize'] = [13,6]

x = np.arange(-1, 5, 0.01)
y = fx(x)

fig, ax = plt.subplots(sharey = True)



ax.plot(x, y, lw = 0.9, color = 'k')
ax.set_xlim([min(x), max(x)])
ax.set_ylim([-3, max(y)+1])
ax.set_xlabel(r'$x$')
ax.set_ylabel(r'$y$')

gd_x, gd_y = gradientdescent(prev_position, alpha, max_iters)

# Creating our animation 
# Setting line and point parameters

line, = ax.plot([], [], 'r', label = 'Gradient descent', lw = 1.5)
point, = ax.plot([], [], 'bo')
value_display = ax.text(0.02, 0.02, '', transform=ax.transAxes)

# Defining an init function for our use-case

def init():
    line.set_data([], [])
    point.set_data([], [])
    value_display.set_text('')

    return line, point, value_display


# Defining the animate function that contains our x and y values

def animate(i):
    # Animate line
    line.set_data(gd_x[:i], gd_y[:i])
    
    # Animate points
    point.set_data(gd_x[i], gd_y[i])

    # Animate value display
    value_display.set_text('Min = ' + str(gd_y[i]))

    return line, point, value_display

# Plotting the Animation

ax.legend(loc = 1)
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(gd_x), interval=120, 
                               repeat_delay=60, blit=True)
plt.close()

# Using the IPython Display module to embed and play our animation

anim.save('animation.gif', writer='imagemagick', fps = 400)

import io
import base64
from IPython.display import HTML

filename = 'animation.gif'

video = io.open(filename, 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<img src="data:image/gif;base64,{0}" type="gif" />'''.format(encoded.decode('ascii')))

# Et voila!
# Out:
# Local Minima is at
# X    2.010308
# Y   -1.999894
# dtype: float64
# <img src="data:image/gif;base64,..." type="gif" />

# %% [markdown]
# ### More code and explanation about GD to appear in the next slides.
#
# **_Thank you!_**
